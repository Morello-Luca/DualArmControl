# %%
import mc_rtc.log as mc_log
log = mc_log.FlatLog("1.bin")
log.keys()
log["qIn"]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mc_rtc.log as mc_log
#       2 log = mc_log.FlatLog("1.bin")   # returns a dict of numpy arrays
#       3 log.keys()
#
# File /usr/lib/python3/dist-packages/mc_rtc/__init__.py:1
# ----> 1 import mc_control
#       2 from . import gui
#       3 from .mc_rtc import *
#
# File /usr/lib/python3/dist-packages/mc_control/__init__.py:1
# ----> 1 from . import fsm
#       2 from .mc_control import *
#
# File /usr/lib/python3/dist-packages/mc_control/fsm/__init__.py:1
# ----> 1 from .fsm import *
#
# ImportError: libmesh_sampling.so: cannot open shared object file: No such file or directory
